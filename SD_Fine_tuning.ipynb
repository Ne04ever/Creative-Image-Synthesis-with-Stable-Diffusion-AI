# %% [markdown]
# # Fine-tuning with Dreambooth

# %% [markdown]
# ## Installing the libraries

# %%
# !pip install "jax[cuda12_local]==0.4.23" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Collecting jax==0.4.23 (from jax[cuda12_local]==0.4.23)
#   Downloading jax-0.4.23-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (0.4.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (1.26.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (3.4.0)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.23->jax[cuda12_local]==0.4.23) (1.13.1)
# Collecting jaxlib==0.4.23+cuda12.cudnn89 (from jax[cuda12_local]==0.4.23)
#   Downloading https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.23%2Bcuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl (131.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 MB 4.8 MB/s eta 0:00:00
# Downloading jax-0.4.23-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: jaxlib, jax
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.33
#     Uninstalling jaxlib-0.4.33:
#       Successfully uninstalled jaxlib-0.4.33
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.33
#     Uninstalling jax-0.4.33:
#       Successfully uninstalled jax-0.4.33
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.87 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# chex 0.1.87 requires jaxlib>=0.4.27, but you have jaxlib 0.4.23+cuda12.cudnn89 which is incompatible.
# flax 0.8.5 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# optax 0.2.3 requires jax>=0.4.27, but you have jax 0.4.23 which is incompatible.
# optax 0.2.3 requires jaxlib>=0.4.27, but you have jaxlib 0.4.23+cuda12.cudnn89 which is incompatible.
# orbax-checkpoint 0.6.4 requires jax>=0.4.26, but you have jax 0.4.23 which is incompatible.
# Successfully installed jax-0.4.23 jaxlib-0.4.23+cuda12.cudnn89

# %%
# !pip install torch==2.1.0+cu121 torchvision==0.16.0+cu121 torchaudio==2.1.0 torchtext==0.16.0+cpu torchdata==0.7.0 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch==2.1.0+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torch-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (2200.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 GB 534.9 kB/s eta 0:00:00
# Collecting torchvision==0.16.0+cu121
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.16.0%2Bcu121-cp310-cp310-linux_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 87.1 MB/s eta 0:00:00
# Collecting torchaudio==2.1.0
#   Downloading https://download.pytorch.org/whl/cu121/torchaudio-2.1.0%2Bcu121-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 72.6 MB/s eta 0:00:00
# Collecting torchtext==0.16.0+cpu
#   Downloading https://download.pytorch.org/whl/torchtext-0.16.0%2Bcpu-cp310-cp310-linux_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.6 MB/s eta 0:00:00
# Collecting torchdata==0.7.0
#   Downloading https://download.pytorch.org/whl/torchdata-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 98.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (3.16.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1.0+cu121) (2024.6.1)
# Collecting triton==2.1.0 (from torch==2.1.0+cu121)
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0+cu121) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0+cu121) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16.0+cu121) (10.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.16.0+cpu) (4.66.5)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.7.0) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1.0+cu121) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0+cu121) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0+cu121) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16.0+cu121) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1.0+cu121) (1.3.0)
# Installing collected packages: triton, torch, torchvision, torchdata, torchaudio, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.0+cu121
#     Uninstalling torchvision-0.20.0+cu121:
#       Successfully uninstalled torchvision-0.20.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.5.0+cu121
#     Uninstalling torchaudio-2.5.0+cu121:
#       Successfully uninstalled torchaudio-2.5.0+cu121
# Successfully installed torch-2.1.0+cu121 torchaudio-2.1.0+cu121 torchdata-0.7.0 torchtext-0.16.0+cpu torchvision-0.16.0+cu121 triton-2.1.0

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.1.0+cu121 requires triton==2.1.0, but you have triton 3.1.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 101.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 31.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 114.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu121 requires torch==2.1.0, but you have torch 2.5.0 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 2.5.0 which is incompatible.
# torchtext 0.16.0+cpu requires torch==2.1.0, but you have torch 2.5.0 which is incompatible.
# torchvision 0.16.0+cu121 requires torch==2.1.0, but you have torch 2.5.0 which is incompatible.

# %% [markdown]
# ## Loading the model

# %%
# !pip install --upgrade diffusers huggingface_hub
# Out:
# WARNING: Ignoring invalid distribution -iffusers (/usr/local/lib/python3.10/dist-packages)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.10/dist-packages (0.31.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.26.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from diffusers) (8.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from diffusers) (3.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from diffusers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from diffusers) (0.4.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from diffusers) (10.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->diffusers) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->diffusers) (2024.8.30)
# WARNING: Ignoring invalid distribution -iffusers (/usr/local/lib/python3.10/dist-packages)

# %% [markdown]
# > Terms of use
#
# * https://huggingface.co/spaces/CompVis/stable-diffusion-license

# %%
model_sd = "stable-diffusion-v1-5/stable-diffusion-v1-5"
output_dir = "/content/stable_diffusion_weights/zwx"

# %%
# !mkdir -p $output_dir

# %%
concepts_list = [
    {
        "instance_prompt": "zwx",
        "class_prompt": "photo of a person",
        "instance_data_dir": "/content/data/zwx",
        "class_data_dir": "/content/data/person"

    }
]

# %%
import json
import os
import random

for c in concepts_list:
  os.makedirs(c["instance_data_dir"], exist_ok=True)

# %%
with open("concepts_list.json", "w") as f:
  json.dump(concepts_list, f, indent=4)

# %% [markdown]
# ### Parameters

# %%
num_imgs = 10
num_class_images = num_imgs * 12
max_num_steps = num_imgs * 80
learning_rate = 1e-6 # 0.0000001
lr_warmup_steps = int(max_num_steps / 10)
print(num_imgs, num_class_images, max_num_steps, learning_rate, lr_warmup_steps)
# Out:
# 10 120 800 1e-06 80

# %%
# !python3 train_dreambooth.py \
  --pretrained_model_name_or_path=$model_sd \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$output_dir \
  --revision="main" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=777 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=$learning_rate \
  --lr_scheduler="constant" \
  --lr_warmup_steps=80 \
  --num_class_images=$num_class_images \
  --sample_batch_size=4 \
  --max_train_steps=$max_num_steps \
  --save_interval=10000 \
  --save_sample_prompt="zwx" \
  --concepts_list="concepts_list.json"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 2024-10-24 15:34:39.816309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 15:34:40.109535: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 15:34:40.193852: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 15:34:40.675995: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 15:34:42.943409: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# config.json: 100% 547/547 [00:00<00:00, 4.10MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:02<00:00, 126MB/s]
# model_index.json: 100% 541/541 [00:00<00:00, 3.89MB/s]
# Fetching 11 files:   0% 0/11 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
# (…)ature_extractor/preprocessor_config.json: 100% 342/342 [00:00<00:00, 2.04MB/s]
# Fetching 11 files:   9% 1/11 [00:00<00:01,  5.64it/s]
#
# text_encoder/config.json: 100% 617/617 [00:00<00:00, 5.08MB/s]
#
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# tokenizer/tokenizer_config.json: 100% 806/806 [00:00<00:00, 5.68MB/s]
#
#
#
# scheduler/scheduler_config.json: 100% 308/308 [00:00<00:00, 2.24MB/s]
#
#
#
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 2.81MB/s]
#
# model.safetensors:   4% 21.0M/492M [00:00<00:03, 149MB/s]
#
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 3.75MB/s]
#
#
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 7.02MB/s]
#
# unet/config.json: 100% 743/743 [00:00<00:00, 4.50MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 1.68MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/3.44G [00:02<06:33, 8.69MB/s]
# model.safetensors:  13% 62.9M/492M [00:02<00:24, 17.8MB/s]
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/3.44G [00:02<02:52, 19.7MB/s]
# model.safetensors:  17% 83.9M/492M [00:02<00:14, 27.6MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 62.9M/3.44G [00:02<01:41, 33.2MB/s]
# model.safetensors:  21% 105M/492M [00:02<00:09, 39.5MB/s]
#
# diffusion_pytorch_model.safetensors:   2% 83.9M/3.44G [00:02<01:12, 46.5MB/s]
# model.safetensors:  26% 126M/492M [00:03<00:07, 49.9MB/s]
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.44G [00:02<00:54, 60.6MB/s]
# model.safetensors:  30% 147M/492M [00:03<00:05, 63.4MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 126M/3.44G [00:03<00:43, 75.3MB/s]
# model.safetensors:  34% 168M/492M [00:03<00:04, 79.7MB/s]
#
# diffusion_pytorch_model.safetensors:   4% 147M/3.44G [00:03<00:35, 92.4MB/s]
# model.safetensors:  40% 199M/492M [00:03<00:02, 103MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 168M/3.44G [00:03<00:30, 108MB/s]
# model.safetensors:  45% 220M/492M [00:03<00:02, 120MB/s]
#
# diffusion_pytorch_model.safetensors:   5% 189M/3.44G [00:03<00:26, 122MB/s]
# model.safetensors:  51% 252M/492M [00:03<00:01, 141MB/s]
#
# diffusion_pytorch_model.safetensors:   6% 210M/3.44G [00:03<00:24, 130MB/s]
# model.safetensors:  55% 273M/492M [00:03<00:01, 146MB/s]
#
# diffusion_pytorch_model.safetensors:   7% 231M/3.44G [00:03<00:22, 142MB/s]
# model.safetensors:  60% 294M/492M [00:04<00:01, 139MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 262M/3.44G [00:03<00:21, 146MB/s]
# model.safetensors:  64% 315M/492M [00:04<00:01, 140MB/s]
#
# diffusion_pytorch_model.safetensors:   8% 283M/3.44G [00:04<00:20, 158MB/s]
# model.safetensors:  68% 336M/492M [00:04<00:01, 139MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 304M/3.44G [00:04<00:21, 144MB/s]
# model.safetensors:  72% 357M/492M [00:04<00:00, 138MB/s]
#
# diffusion_pytorch_model.safetensors:   9% 325M/3.44G [00:04<00:22, 138MB/s]
# model.safetensors:  77% 377M/492M [00:06<00:03, 28.9MB/s]
#
# diffusion_pytorch_model.safetensors:  10% 346M/3.44G [00:06<01:46, 29.1MB/s]
# model.safetensors:  83% 409M/492M [00:06<00:01, 43.2MB/s]
#
# diffusion_pytorch_model.safetensors:  11% 377M/3.44G [00:06<01:11, 43.1MB/s]
# model.safetensors:  87% 430M/492M [00:06<00:01, 54.1MB/s]
#
# diffusion_pytorch_model.safetensors:  12% 398M/3.44G [00:06<00:56, 53.7MB/s]
# model.safetensors:  92% 451M/492M [00:07<00:00, 66.3MB/s]
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.44G [00:06<00:47, 63.3MB/s]
# model.safetensors:  96% 472M/492M [00:07<00:00, 76.3MB/s]
#
# diffusion_pytorch_model.safetensors:  13% 440M/3.44G [00:07<00:38, 77.4MB/s]
# model.safetensors: 100% 492M/492M [00:07<00:00, 66.4MB/s]
# Fetching 11 files:  45% 5/11 [00:07<00:09,  1.60s/it]
#
# diffusion_pytorch_model.safetensors:  13% 461M/3.44G [00:07<00:32, 92.5MB/s]
#
# diffusion_pytorch_model.safetensors:  14% 493M/3.44G [00:07<00:24, 118MB/s]
#
# diffusion_pytorch_model.safetensors:  15% 524M/3.44G [00:07<00:20, 145MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 556M/3.44G [00:07<00:16, 173MB/s]
#
# diffusion_pytorch_model.safetensors:  17% 587M/3.44G [00:07<00:14, 193MB/s]
#
# diffusion_pytorch_model.safetensors:  18% 619M/3.44G [00:07<00:13, 211MB/s]
#
# diffusion_pytorch_model.safetensors:  19% 650M/3.44G [00:07<00:13, 213MB/s]
#
# diffusion_pytorch_model.safetensors:  20% 682M/3.44G [00:08<00:12, 227MB/s]
#
# diffusion_pytorch_model.safetensors:  21% 713M/3.44G [00:08<00:11, 236MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 744M/3.44G [00:08<00:11, 236MB/s]
#
# diffusion_pytorch_model.safetensors:  23% 776M/3.44G [00:08<00:10, 247MB/s]
#
# diffusion_pytorch_model.safetensors:  23% 807M/3.44G [00:08<00:10, 245MB/s]
#
# diffusion_pytorch_model.safetensors:  24% 839M/3.44G [00:08<00:10, 253MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 870M/3.44G [00:08<00:10, 256MB/s]
#
# diffusion_pytorch_model.safetensors:  26% 902M/3.44G [00:08<00:10, 250MB/s]
#
# diffusion_pytorch_model.safetensors:  27% 933M/3.44G [00:09<00:10, 248MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 965M/3.44G [00:09<00:09, 249MB/s]
#
# diffusion_pytorch_model.safetensors:  29% 996M/3.44G [00:09<00:09, 249MB/s]
#
# diffusion_pytorch_model.safetensors:  30% 1.03G/3.44G [00:09<00:09, 256MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 1.06G/3.44G [00:09<00:09, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  32% 1.09G/3.44G [00:09<00:09, 247MB/s]
#
# diffusion_pytorch_model.safetensors:  33% 1.12G/3.44G [00:09<00:09, 251MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 1.15G/3.44G [00:09<00:09, 251MB/s]
#
# diffusion_pytorch_model.safetensors:  34% 1.18G/3.44G [00:10<00:08, 257MB/s]
#
# diffusion_pytorch_model.safetensors:  35% 1.22G/3.44G [00:10<00:08, 256MB/s]
#
# diffusion_pytorch_model.safetensors:  36% 1.25G/3.44G [00:10<00:08, 250MB/s]
#
# diffusion_pytorch_model.safetensors:  37% 1.28G/3.44G [00:10<00:08, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 1.31G/3.44G [00:10<00:08, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  39% 1.34G/3.44G [00:10<00:08, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  40% 1.37G/3.44G [00:10<00:08, 258MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 1.41G/3.44G [00:10<00:07, 260MB/s]
#
# diffusion_pytorch_model.safetensors:  42% 1.44G/3.44G [00:11<00:08, 247MB/s]
#
# diffusion_pytorch_model.safetensors:  43% 1.47G/3.44G [00:11<00:07, 259MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 1.50G/3.44G [00:11<00:07, 252MB/s]
#
# diffusion_pytorch_model.safetensors:  45% 1.53G/3.44G [00:11<00:07, 253MB/s]
#
# diffusion_pytorch_model.safetensors:  45% 1.56G/3.44G [00:11<00:07, 260MB/s]
#
# diffusion_pytorch_model.safetensors:  46% 1.59G/3.44G [00:11<00:07, 261MB/s]
#
# diffusion_pytorch_model.safetensors:  47% 1.63G/3.44G [00:11<00:07, 254MB/s]
#
# diffusion_pytorch_model.safetensors:  48% 1.66G/3.44G [00:11<00:07, 254MB/s]
#
# diffusion_pytorch_model.safetensors:  49% 1.69G/3.44G [00:12<00:06, 259MB/s]
#
# diffusion_pytorch_model.safetensors:  50% 1.72G/3.44G [00:12<00:06, 251MB/s]
#
# diffusion_pytorch_model.safetensors:  51% 1.75G/3.44G [00:12<00:06, 259MB/s]
#
# diffusion_pytorch_model.safetensors:  52% 1.78G/3.44G [00:12<00:06, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  53% 1.81G/3.44G [00:12<00:06, 260MB/s]
#
# diffusion_pytorch_model.safetensors:  54% 1.85G/3.44G [00:12<00:06, 260MB/s]
#
# diffusion_pytorch_model.safetensors:  55% 1.88G/3.44G [00:12<00:06, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  56% 1.91G/3.44G [00:12<00:05, 261MB/s]
#
# diffusion_pytorch_model.safetensors:  56% 1.94G/3.44G [00:13<00:05, 255MB/s]
#
# diffusion_pytorch_model.safetensors:  57% 1.97G/3.44G [00:13<00:06, 230MB/s]
#
# diffusion_pytorch_model.safetensors:  58% 2.00G/3.44G [00:13<00:06, 222MB/s]
#
# diffusion_pytorch_model.safetensors:  59% 2.03G/3.44G [00:13<00:06, 222MB/s]
#
# diffusion_pytorch_model.safetensors:  60% 2.07G/3.44G [00:13<00:06, 212MB/s]
#
# diffusion_pytorch_model.safetensors:  61% 2.10G/3.44G [00:13<00:06, 213MB/s]
#
# diffusion_pytorch_model.safetensors:  62% 2.13G/3.44G [00:13<00:06, 204MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 2.15G/3.44G [00:14<00:06, 201MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 2.18G/3.44G [00:14<00:05, 211MB/s]
#
# diffusion_pytorch_model.safetensors:  64% 2.21G/3.44G [00:14<00:05, 205MB/s]
#
# diffusion_pytorch_model.safetensors:  65% 2.23G/3.44G [00:14<00:06, 196MB/s]
#
# diffusion_pytorch_model.safetensors:  66% 2.26G/3.44G [00:14<00:05, 202MB/s]
#
# diffusion_pytorch_model.safetensors:  67% 2.30G/3.44G [00:14<00:05, 217MB/s]
#
# diffusion_pytorch_model.safetensors:  68% 2.33G/3.44G [00:14<00:04, 231MB/s]
#
# diffusion_pytorch_model.safetensors:  69% 2.36G/3.44G [00:15<00:05, 209MB/s]
#
# diffusion_pytorch_model.safetensors:  70% 2.39G/3.44G [00:16<00:18, 56.3MB/s]
#
# diffusion_pytorch_model.safetensors:  70% 2.42G/3.44G [00:16<00:13, 73.3MB/s]
#
# diffusion_pytorch_model.safetensors:  71% 2.45G/3.44G [00:17<00:12, 78.4MB/s]
#
# diffusion_pytorch_model.safetensors:  72% 2.49G/3.44G [00:17<00:09, 101MB/s]
#
# diffusion_pytorch_model.safetensors:  73% 2.52G/3.44G [00:17<00:07, 126MB/s]
#
# diffusion_pytorch_model.safetensors:  74% 2.55G/3.44G [00:17<00:06, 148MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 2.58G/3.44G [00:17<00:05, 165MB/s]
#
# diffusion_pytorch_model.safetensors:  76% 2.61G/3.44G [00:17<00:04, 180MB/s]
#
# diffusion_pytorch_model.safetensors:  77% 2.64G/3.44G [00:17<00:04, 199MB/s]
#
# diffusion_pytorch_model.safetensors:  78% 2.67G/3.44G [00:17<00:03, 213MB/s]
#
# diffusion_pytorch_model.safetensors:  79% 2.71G/3.44G [00:18<00:03, 223MB/s]
#
# diffusion_pytorch_model.safetensors:  80% 2.74G/3.44G [00:18<00:02, 236MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.44G [00:18<00:02, 243MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.44G [00:18<00:02, 241MB/s]
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [00:18<00:02, 242MB/s]
#
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.44G [00:18<00:02, 240MB/s]
#
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.44G [00:18<00:02, 253MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.44G [00:18<00:02, 254MB/s]
#
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.44G [00:19<00:01, 247MB/s]
#
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.44G [00:19<00:01, 253MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.44G [00:19<00:01, 258MB/s]
#
# diffusion_pytorch_model.safetensors:  89% 3.05G/3.44G [00:19<00:01, 262MB/s]
#
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.44G [00:19<00:01, 254MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.11G/3.44G [00:19<00:01, 254MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 3.15G/3.44G [00:19<00:01, 252MB/s]
#
# diffusion_pytorch_model.safetensors:  92% 3.18G/3.44G [00:19<00:01, 258MB/s]
#
# diffusion_pytorch_model.safetensors:  93% 3.21G/3.44G [00:20<00:00, 253MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 3.24G/3.44G [00:20<00:00, 256MB/s]
#
# diffusion_pytorch_model.safetensors:  95% 3.27G/3.44G [00:20<00:00, 256MB/s]
#
# diffusion_pytorch_model.safetensors:  96% 3.30G/3.44G [00:20<00:00, 258MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 3.33G/3.44G [00:20<00:00, 249MB/s]
#
# diffusion_pytorch_model.safetensors:  98% 3.37G/3.44G [00:20<00:00, 251MB/s]
#
# diffusion_pytorch_model.safetensors:  99% 3.40G/3.44G [00:20<00:00, 257MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:20<00:00, 164MB/s]
# Fetching 11 files: 100% 11/11 [00:21<00:00,  1.94s/it]
# Loading pipeline components...:  67% 4/6 [00:14<00:08,  4.37s/it]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loading pipeline components...:  83% 5/6 [00:15<00:03,  3.12s/it]10/24/2024 15:35:30 - INFO - __main__ - Number of class images to sample: 120.
# Generating class images: 100% 30/30 [06:48<00:00, 13.60s/it]
# vae/config.json: 100% 547/547 [00:00<00:00, 4.06MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 275MB/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/configuration_utils.py:245: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Caching latents: 100% 120/120 [00:25<00:00,  4.65it/s]
# Steps: 100% 800/800 [13:18<00:00,  1.00it/s, loss=0.276, lr=1e-6]
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 81.45it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:05<00:16,  5.50s/it]
# Generating samples:  50% 2/4 [00:09<00:08,  4.42s/it]
# Generating samples:  75% 3/4 [00:12<00:04,  4.10s/it]
# Generating samples: 100% 4/4 [00:16<00:00,  4.14s/it]
# [*] Weights saved at /content/stable_diffusion_weights/zwx/800
# Steps: 100% 800/800 [14:05<00:00,  1.06s/it, loss=0.276, lr=1e-6]

# %%
from natsort import natsorted
from glob import glob
import os

weights_dir = natsorted(glob(output_dir + os.sep + '*'))[-1]
print('Weights directory: ', weights_dir)
# Out:
# Weights directory:  /content/stable_diffusion_weights/zwx/800

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

def grid_img(imgs, rows=1, cols=3, scale=1):
  assert len(imgs) == rows * cols

  w, h = imgs[0].size
  w, h = int(w*scale), int(h*scale)

  grid = Image.new('RGB', size=(cols*w, rows*h))
  grid_w, grid_h = grid.size

  for i, img in enumerate(imgs):
      img = img.resize((w,h))
      grid.paste(img, box=(i%cols*w, i//cols*h))
  return grid

# %%
weights_folder = output_dir
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key = lambda x: int(x))

imgs_test = []

for imgs, folder in enumerate(folders):
  folder_path = os.path.join(weights_folder, folder)
  image_folder = os.path.join(folder_path, "samples")
  images = [f for f in os.listdir(image_folder)]

  for i in images:
    img_path = os.path.join(image_folder, i)
    r = Image.open(img_path)
    imgs_test.append(r)

grid_img(imgs_test, rows=1, cols=4, scale=1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Convert the weights into (checkpoint)

# %%
ckpt_path = weights_dir + "/model.ckpt"

half_arg = "--half" # fp16

# !python convert_diffusers_to_original_stable_diffusion.py --model_path $weights_dir  --checkpoint_path $ckpt_path $half_arg
print(f"Converted to ckpt and saved in {ckpt_path}")
# Out:
# Converted to ckpt and saved in /content/stable_diffusion_weights/zwx/800/model.ckpt

# %% [markdown]
# ## Inference (tests)

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
model_path = weights_dir
print(model_path)
# Out:
# /content/stable_diffusion_weights/zwx/800

# %%
pipe = StableDiffusionPipeline.from_pretrained(model_path, torch_dtype=torch.float16).to('cuda')
# Out:
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
seed = 777

# %% [markdown]
# ## Generating images

# %%
prompt = "face portrait of zwx person in the snow, realistic, hd, vivid, sunset"
negative_prompt = "bad anatomy, ugly, deformed, desfigured, distorted face, poorly drawn hands, poorly drawn face, poorly drawn feet, blurry, low quality, low definition, lowres, out of frame, out of image, cropped, cut off, signature, watermark"
num_samples = 5
guidance_scale = 7.5
num_inference_steps = 30
height = 512
width = 512

seed = random.randint(0, 2147483647)
print("Seed: {}".format(str(seed)))
generator = torch.Generator(device='cuda').manual_seed(seed)

with autocast("cuda"), torch.inference_mode():
    imgs = pipe(
        prompt,
        negative_prompt=negative_prompt,
        height=height, width=width,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=generator
    ).images

for img in imgs:
    display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Testing multiple prompts

# %%
prompt = ["photo of zwx person, closeup, mountain fuji in the background, natural lighting",
          "photo of zwx person in the desert, closeup, pyramids in the background, natural lighting, frontal face",
          "photo of zwx person in the forest, natural lighting, frontal face",
          "photo of zwx person as an astronaut, natural lighting, frontal face, closeup, starry sky in the background",
          "face portrait of zwx in the snow, realistic, hd, vivid, sunset"]

negative_prompt = ["bad anatomy, ugly, deformed, desfigured, distorted face, poorly drawn hands, poorly drawn face, poorly drawn feet, blurry, low quality, low definition, lowres, out of frame, out of image, cropped, cut off, signature, watermark" ] * len(prompt)
num_samples = 1
guidance_scale = 7.5
num_inference_steps = 30
height = 512
width = 512

seed = random.randint(0, 2147483647) # random value
print("Seed: {}".format(str(seed)))
generator = torch.Generator(device='cuda').manual_seed(seed)

with autocast("cuda"), torch.inference_mode():
    imgs = pipe(
        prompt,
        negative_prompt=negative_prompt,
        height=height, width=width,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=generator
    ).images

for img in imgs:
    display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
